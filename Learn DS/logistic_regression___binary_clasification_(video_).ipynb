# %% [markdown]
# ![WhatsApp Image 2024-04-06 at 01.32.39.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Regression for predicted the number wheareas classification for predicted a categorical

# %% [markdown]
# ![WhatsApp Image 2024-04-06 at 01.50.24 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# This is classification types. if ther is two predicted classification else called as **Binarry Classification** wheareas if there is there predicted classification else called as **Multiclass Classification**
#
#
# code on him github: https://github.com/codebasics/py/blob/master/ML/7_logistic_reg/7_logistic_regression.ipynb

# %%
# !pip install scikit-learn

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/7_logistic_reg/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
# i'm not understand for this graph
plt.scatter(df.age, df.bought_insurance, marker="+", color="red")

# %% [markdown]
# # Prepare data test and data train

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[["age"]], df.bought_insurance, test_size=0.1)

x_test
# Out:
#     age
# 21   26
# 3    52
# 11   28

# %% [markdown]
# # Applied the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 0])

# %%
model.score(x_test, y_test)
# Out:
# 0.6666666666666666

# %%
model.predict_proba(x_test)
# Out:
# array([[0.81502831, 0.18497169],
#        [0.07310448, 0.92689552],
#        [0.76378803, 0.23621197]])

# %%
# Do the prediction
model.predict(25)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-57ab2bae1458> in <cell line: 2>()
#       1 # Do the prediction
# ----> 2 model.predict(25)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     417         """
#     418         xp, _ = get_namespace(X)
# --> 419         scores = self.decision_function(X)
#     420         if len(scores.shape) == 1:
#     421             indices = xp.astype(scores > 0, int)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     398         xp, _ = get_namespace(X)
#     399
# ...
